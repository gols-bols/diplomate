# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "from pptx import Presentation\n",
    "from pathlib import Path\n",
    "root = Path('c:/Users/Admin/Downloads/kurso-main 2')\n",
    "pptx_path = root / 'docs' / 'Презентация_к_уров\u0430_\u043a_\u043a\u0443\u0440\u0441\u043e\u0432\u043e\u0439.pptx'\n",
    "print('exists', pptx_path.exists())\n",
    "if pptx_path.exists():\n",
    "    prs = Presentation(str(pptx_path))\n",
    "    print('slides', len(prs.slides))\n",
    "    for i, slide in enumerate(prs.slides, start=1):\n",
    "        texts = [shape.text for shape in slide.shapes if hasattr(shape, 'text')]\n",
    "        print(i, texts[:2])\n"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
